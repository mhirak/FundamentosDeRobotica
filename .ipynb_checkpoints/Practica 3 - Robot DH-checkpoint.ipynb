# %%
# Esta linea nos sirve para que los gráficos sean interactivos
# Dependiendo de su configuración puede ser necesaria o no
# %matplotlib notebook
# Importamos la librería de robótica y le designamos el alias "rtb"
import roboticstoolbox as rtb
# Para manejar los ángulos, que la librería trabaja en radianes
from math import pi, inf

# %%
# Designo las longitudes de brazo
l1 = 3
l2 = 2

# %%
# Definimos el primer eslabón, sólo pasamos el parámetro a porque es el único no nulo 
# Ademas le pasamos el parametro qlim para limitar el giro
L1 = rtb.RevoluteDH(a=l1, qlim=[-pi/2, pi/2])
L1
# Out:
# RevoluteDH(d=0, a=3, ⍺=0, qlim=[-1.57, 1.57], m=0, Jm=0, B=0, G=0)

# %%
# Lo mismo con el segundo eslabón
L2 = rtb.RevoluteDH(a=l2)
L2
# Out:
# RevoluteDH(d=0, a=2, ⍺=0, m=0, Jm=0, B=0, G=0)

# %%
# Finalmente, creamos el robot uniendo los eslabones recién creados
# Observar que, como a un eslabon le estableci limites, 
# todos los eslabones establecen su lìmite en -pi, +pi (360º)
robot = rtb.DHRobot([L1,L2])
robot
# Out:
# DHRobot: noname, 2 joints (RR), dynamics, standard DH parameters
# ┏━━━━┳━━━━┳━━━━┳━━━━━━┳━━━━━━━━━┳━━━━━━━━┓
# ┃θⱼ  ┃ dⱼ ┃ aⱼ ┃  ⍺ⱼ  ┃   q⁻    ┃   q⁺   ┃
# ┣━━━━╋━━━━╋━━━━╋━━━━━━╋━━━━━━━━━╋━━━━━━━━┫
# ┃ q1 ┃  0 ┃  3 ┃ 0.0° ┃  -90.0° ┃  90.0° ┃
# ┃ q2 ┃  0 ┃  2 ┃ 0.0° ┃ -180.0° ┃ 180.0° ┃
# ┗━━━━┻━━━━┻━━━━┻━━━━━━┻━━━━━━━━━┻━━━━━━━━┛

# %%
# Añadimos el primer punto para el robot,
# en este caso, sus dos ejes en cero.
robot.addconfiguration('zero',[0,0])
robot.zero
# Out:
# array([0., 0.])

# %%
# Añadimos otro punto.
# Ahora, los giros son relativos 
robot.addconfiguration('t1',[pi/2,pi/4])
robot.t1
# Out:
# array([1.57079633, 0.78539816])

# %%
robot.plot(robot.t1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# PyPlot3D backend, t = 0.05, scene:
#   noname

# %%
# Importamos la libreria spatialmath, para poder plotear ternas en el mismo grafico
from spatialmath import *
from spatialmath.base import *

# %%
# Creamos una terna en (0,0,0) que sera nuestro origen
S0 = SE3()

# %%
# Ploteamos todo junto
robot.plot(robot.t1, block = False)
trplot(S0.A, frame='S0', block = False)
angulo_q1_pos_t1 = robot.t1[0]
S1 = L1.A(q=pi/2)
print(S1)
trplot(S1, frame = 'S1')
# Out:
#    0        -1         0         0
#    1         0         0         3
#    0         0         1         0
#    0         0         0         1
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Input In [14], in <cell line: 7>()
#       5 S1 = L1.A(q=pi/2)
#       6 print(S1)
# ----> 7 trplot(S1, frame = 'S1')
#
# File ~/anaconda3/envs/robotica/lib/python3.10/site-packages/spatialmath/base/transforms3d.py:2645, in trplot(T, color, frame, axislabel, axissubscript, textcolor, labels, length, style, originsize, origincolor, projection, block, anaglyph, wtl, width, ax, dims, d2, flo, **kwargs)
#    2642 else:
#    2643     # assume it is an iterable
#    2644     for Tk in T:
# -> 2645         trplot(
#    2646             Tk,
#    2647             ax=ax,
#    2648             block=block,
#    2649             dims=dims,
#    2650             color=color,
#    2651             frame=frame,
#    2652             textcolor=textcolor,
#    2653             labels=labels,
#    2654             length=length,
#    2655             style=style,
#    2656             projection=projection,
#    2657             originsize=originsize,
#    2658             origincolor=origincolor,
#    2659             wtl=wtl,
#    2660             width=width,
#    2661             d2=d2,
#    2662             flo=flo,
#    2663             anaglyph=anaglyph,
#    2664             **kwargs
#    2665         )
#    2666     return
#    2668 if dims is not None:
#
# File ~/anaconda3/envs/robotica/lib/python3.10/site-packages/spatialmath/base/transforms3d.py:2645, in trplot(T, color, frame, axislabel, axissubscript, textcolor, labels, length, style, originsize, origincolor, projection, block, anaglyph, wtl, width, ax, dims, d2, flo, **kwargs)
#    2642 else:
#    2643     # assume it is an iterable
#    2644     for Tk in T:
# -> 2645         trplot(
#    2646             Tk,
#    2647             ax=ax,
#    2648             block=block,
#    2649             dims=dims,
#    2650             color=color,
#    2651             frame=frame,
#    2652             textcolor=textcolor,
#    2653             labels=labels,
#    2654             length=length,
#    2655             style=style,
#    2656             projection=projection,
#    2657             originsize=originsize,
#    2658             origincolor=origincolor,
#    2659             wtl=wtl,
#    2660             width=width,
#    2661             d2=d2,
#    2662             flo=flo,
#    2663             anaglyph=anaglyph,
#    2664             **kwargs
#    2665         )
#    2666     return
#    2668 if dims is not None:
#
#     [... skipping similar frames: trplot at line 2645 (2964 times)]
#
# File ~/anaconda3/envs/robotica/lib/python3.10/site-packages/spatialmath/base/transforms3d.py:2645, in trplot(T, color, frame, axislabel, axissubscript, textcolor, labels, length, style, originsize, origincolor, projection, block, anaglyph, wtl, width, ax, dims, d2, flo, **kwargs)
#    2642 else:
#    2643     # assume it is an iterable
#    2644     for Tk in T:
# -> 2645         trplot(
#    2646             Tk,
#    2647             ax=ax,
#    2648             block=block,
#    2649             dims=dims,
#    2650             color=color,
#    2651             frame=frame,
#    2652             textcolor=textcolor,
#    2653             labels=labels,
#    2654             length=length,
#    2655             style=style,
#    2656             projection=projection,
#    2657             originsize=originsize,
#    2658             origincolor=origincolor,
#    2659             wtl=wtl,
#    2660             width=width,
#    2661             d2=d2,
#    2662             flo=flo,
#    2663             anaglyph=anaglyph,
#    2664             **kwargs
#    2665         )
#    2666     return
#    2668 if dims is not None:
#
# File ~/anaconda3/envs/robotica/lib/python3.10/site-packages/spatialmath/base/transforms3d.py:2644, in trplot(T, color, frame, axislabel, axissubscript, textcolor, labels, length, style, originsize, origincolor, projection, block, anaglyph, wtl, width, ax, dims, d2, flo, **kwargs)
#    2641     pass
#    2642 else:
#    2643     # assume it is an iterable
# -> 2644     for Tk in T:
#    2645         trplot(
#    2646             Tk,
#    2647             ax=ax,
#    (...)
#    2664             **kwargs
#    2665         )
#    2666     return
#
# File ~/anaconda3/envs/robotica/lib/python3.10/_collections_abc.py:1038, in Sequence.__iter__(self)
#    1036 try:
#    1037     while True:
# -> 1038         v = self[i]
#    1039         yield v
#    1040         i += 1
#
# File ~/anaconda3/envs/robotica/lib/python3.10/site-packages/spatialmath/baseposelist.py:301, in BasePoseList.__getitem__(self, i)
#     299     return self.__class__([self.data[k] for k in range(i.start or 0, end, i.step or 1)])
#     300 else:
# --> 301     return self.__class__(self.data[i], check=False)
#
# File ~/anaconda3/envs/robotica/lib/python3.10/site-packages/spatialmath/pose3d.py:761, in SE3.__init__(self, x, y, z, check)
#     732 """
#     733 Construct new SE(3) object
#     734
#    (...)
#     756 :SymPy: supported
#     757 """
#     758 if y is None and z is None:
#     759     # just one argument passed
# --> 761     if super().arghandler(x, check=check):
#     762         return
#     763     elif isinstance(x, SO3):
#
# File ~/anaconda3/envs/robotica/lib/python3.10/site-packages/spatialmath/baseposelist.py:182, in BasePoseList.arghandler(self, arg, convertfrom, check)
#     178 if arg is None:
#     179     # empty constructor
#     180     self.data = [self._identity()]
# --> 182 elif isinstance(arg, np.ndarray):
#     183     # it's a numpy array
#     184     x = self._import(arg, check=check)
#     185     if x is not None:
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
robot.t1[0]
# Out:
# 1.5707963267948966

# %%
L1.A(q=robot.t1[0])
# Out:
#    0        -1         0         0
#    1         0         0         3
#    0         0         1         0
#    0         0         0         1

# %%
S1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-143-6731f6169737> in <module>
# ----> 1 S1
#
# NameError: name 'S1' is not defined
